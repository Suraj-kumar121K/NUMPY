# %% [markdown]
# # import NumPy

# %%
import numpy as np

# %% [markdown]
# # Question Solve

# %% [markdown]
# ### 🔹 PART 1: 1D Array Indexing (1–20)

# %% [markdown]
# 1. Create a 1D NumPy array of 10 elements and print the first element

# %% [markdown]
# 2. Print the last element using negative indexing

# %% [markdown]
# 3. Print the 3rd element of an array

# %% [markdown]
# 4. Access the middle element of an array

# %% [markdown]
# 5. Replace the first element with 100

# %% [markdown]
# 6. Replace the last element with 0

# %% [markdown]
# 7. Print all elements except the first

# %% [markdown]
# 8. Print all elements except the last

# %% [markdown]
# 9. Access elements using negative indices

# %% [markdown]
# 10. Count total elements using indexing logic

# %% [markdown]
# 11. Print even index elements

# %% [markdown]
# 12. Print odd index elements

# %% [markdown]
# 13. Access every second element

# %% [markdown]
# 14. Access every third element

# %% [markdown]
# 15. Reverse an array using slicing

# %% [markdown]
# 16. Check if slicing changes the original array

# %% [markdown]
# 17. Copy sliced array and modify it

# %% [markdown]
# 18. Extract first 5 elements

# %% [markdown]
# 19. Extract last 5 elements

# %% [markdown]
# 20. Extract alternate elements from end to start

# %% [markdown]
# # 🔹 PART 2: 1D Array Slicing (21–35)

# %% [markdown]
# 21. Slice array from index 2 to 6

# %% [markdown]
# 22. Slice first half of the array

# %% [markdown]
# 23. Slice second half of the array

# %% [markdown]
# 24. Slice array excluding first and last element

# %% [markdown]
# 25. Slice using step = 2

# %% [markdown]
# 26. Slice using step = -1

# %% [markdown]
# 27. Slice from index 5 to 1 (reverse)

# %% [markdown]
# 28. Slice array into two equal parts

# %% [markdown]
# 29. Slice array without start index

# %% [markdown]
# 30. Slice array without stop index

# %% [markdown]
# 31. Slice array using only step

# %% [markdown]
# 32. Create a view and modify it

# %% [markdown]
# 33. Create a copy using slicing

# %% [markdown]
# 34. Compare view vs copy

# %% [markdown]
# 35. Slice array using variable indices

# %% [markdown]
# # 🔹 PART 3: 2D Array Indexing (36–55)

# %% [markdown]
# 36. Create a 3×3 array and access element at (0,0)

# %% [markdown]
# 37. Access element at last row last column

# %% [markdown]
# 38. Access center element

# %% [markdown]
# 39. Access first row

# %% [markdown]
# 40. Access last row

# %% [markdown]
# 41. Access first column

# %% [markdown]
# 42. Access last column

# %% [markdown]
# 43. Access element using negative indexing

# %% [markdown]
# 44. Replace element at (1,1) with 99

# %% [markdown]
# 45. Access second row third column

# %% [markdown]
# 46. Access all elements of a specific row

# %% [markdown]
# 47. Access all elements of a specific column

# %% [markdown]
# 48. Access diagonal element manually

# %% [markdown]
# 49. Access top-right element

# %% [markdown]
# 50. Access bottom-left element

# %% [markdown]
# 51. Count rows using indexing

# %% [markdown]
# 52. Count columns using indexing

# %% [markdown]
# 53. Access multiple elements using index list

# %% [markdown]
# 54. Modify one full row

# %% [markdown]
# 55. Modify one full column

# %% [markdown]
# # 🔹 PART 4: 2D Array Slicing (56–75)

# %% [markdown]
# 56. Slice first two rows
#
# Slice last two rows
#
# Slice first two columns
#
# Slice last two columns
#
# Extract a 2×2 sub-matrix from top-left
#
# Extract a 2×2 sub-matrix from bottom-right
#
# Slice middle row only
#
# Slice middle column only
#
# Slice alternate rows
#
# Slice alternate columns
#
# Slice rows with step 2
#
# Slice columns with step 2
#
# Reverse rows of matrix
#
# Reverse columns of matrix
#
# Reverse entire matrix
#
# Slice matrix excluding border
#
# Replace sliced part with zeros
#
# Check if slicing affects original matrix
#
# Copy slice and modify it
#
# Convert slice to 1D array

# %% [markdown]
# # 🔹 PART 5: Boolean Indexing (76–90)

# %% [markdown]
# 76. Select elements greater than 10
#
# Select elements less than 5
#
# Select even numbers
#
# Select odd numbers
#
# Replace values > 50 with 0
#
# Count elements satisfying a condition
#
# Select elements between 10 and 30
#
# Apply condition on 2D array
#
# Replace negative values with 0
#
# Select rows where value > threshold
#
# Boolean indexing on columns
#
# Combine two conditions using &
#
# Combine two conditions using |
#
# Use np.where with indexing
#
# Boolean mask and slicing together

# %% [markdown]
# # 🔹 PART 6: Fancy Indexing (91–100)

# %% [markdown]
# 91. Access elements using index list
#
# Access multiple rows using fancy indexing
#
# Access multiple columns using fancy indexing
#
# Change values at specific indices
#
# Extract random elements using index array
#
# Access diagonal using fancy indexing
#
# Select rows in custom order
#
# Select columns in custom order
#
# Combine fancy + boolean indexing
#
# Difference between fancy indexing and slicing (code example)
