# %% [markdown]
# # Handling Missing Values in NumPy

# %% [markdown]
# # 🔹 What are Missing Values?
#
# ### Missing values are data points that are:
# - Not available
# - Undefined
# - Invalid
#
# # missing values are usually represented as:
# - np.nan → for floating-point data
# - None → becomes nan in NumPy arrays (float type)

# %% [markdown]
# ### 🔹 Representation of Missing Values
# # 1️⃣ np.nan
# - 👉 np.nan = Not a Number (float type)

# %%
import numpy as np

a = np.array([1, 2, np.nan, 4])

# %% [markdown]
# ### 2️⃣ None
# - converted to nan (dtype becomes float)

# %%
b = np.array([1, 2, None, 4])

# %% [markdown]
# ### 🔹 Detecting Missing Values
# ### ✅ np.isnan()
# - Used to check missing values.

# %%
np.isnan(a)
# Out:
# array([False, False,  True, False])

# %% [markdown]
# # ✅ Count Missing Values

# %%
np.isnan(a).sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## 🔹 Removing Missing Values
# ### ✅ Remove nan Values

# %%
clean = a[~np.isnan(a)]
print(clean)
# Out:
# [1. 2. 4.]

# %% [markdown]
# ## 🔹 Replacing Missing Values
# ### 1️⃣ Replace with a Fixed Value
# - ➡ Replaces nan with 0

# %%
np.nan_to_num(a, nan=0)
# Out:
# array([1., 2., 0., 4.])

# %% [markdown]
# # 2️⃣ Replace with Mean

# %%
mean_value = np.nanmean(a)
a_filled = np.where(np.isnan(a), mean_value, a)

# %% [markdown]
# ## 3️⃣ Replace with Median

# %%
median = np.nanmedian(a)
a_filled = np.where(np.isnan(a), median, a)

# %% [markdown]
# ## 🔹 NumPy Functions that Ignore nan
# - NumPy provides special functions that automatically ignore missing values.

# %%
np.nanmean(a)
np.nansum(a)
np.nanmin(a)
np.nanmax(a)
np.nanstd(a)
# Out:
# np.float64(1.247219128924647)

# %% [markdown]
# # 🔹 Missing Values in 2D Arrays

# %%
arr = np.array([[1, 2, np.nan],
                [4, np.nan, 6]])

# %% [markdown]
# Remove Rows with Missing Values

# %%
arr[~np.isnan(arr).any(axis=1)]
# Out:
# array([], shape=(0, 3), dtype=float64)

# %% [markdown]
# Replace Column-wise Mean

# %%
col_mean = np.nanmean(arr, axis=0)
inds = np.where(np.isnan(arr))
arr[inds] = np.take(col_mean, inds[1])

# %% [markdown]
# ### 🔹 Boolean Masking

# %%
mask = np.isnan(arr)
arr[mask] = 0
