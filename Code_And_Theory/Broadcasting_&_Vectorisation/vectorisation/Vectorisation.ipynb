# %% [markdown]
# # ⚡ Vectorisation in NumPy

# %% [markdown]
# ## 🔹 What is Vectorisation?
# - Vectorisation means performing operations on entire arrays at once instead of using Python loops.

# %% [markdown]
# ## 🔹 Why Vectorisation?
# - Python loops are slow
# - Vectorised operations are faster
# - Code becomes shorter and easier to read

# %% [markdown]
# ## ✅ With Vectorisation (Fast)

# %%
import numpy as np

a = np.array([0, 1, 2, 3, 4])
a * a
# Out:
# array([ 0,  1,  4,  9, 16])

# %% [markdown]
# ## 🔹 Common Vectorised Operations
# - a + b
# - a - b
# - a * b
# - a / b
# - np.sqrt(a)
# - np.sum(a)
# - np.mean(a)
